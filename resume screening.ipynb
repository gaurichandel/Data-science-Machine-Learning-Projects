# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
from pandas.plotting import scatter_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
resumeDataSet = pd.read_csv("C:\\Users\\Gauri Chandel\\Desktop\\AI-ML Projects\\resume screening project\\UpdatedResumeDataSet.csv" ,encoding='utf-8')
resumeDataSet['cleaned_resume'] = ''
resumeDataSet.head()
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#   cleaned_resume
# 0
# 1
# 2
# 3
# 4

# %%
print (resumeDataSet['Category'].unique())
# Out:
# ['Data Science' 'HR' 'Advocate' 'Arts' 'Web Designing'
#  'Mechanical Engineer' 'Sales' 'Health and fitness' 'Civil Engineer'
#  'Java Developer' 'Business Analyst' 'SAP Developer' 'Automation Testing'
#  'Electrical Engineering' 'Operations Manager' 'Python Developer'
#  'DevOps Engineer' 'Network Security Engineer' 'PMO' 'Database' 'Hadoop'
#  'ETL Developer' 'DotNet Developer' 'Blockchain' 'Testing']

# %%
print (resumeDataSet['Category'].value_counts())
# Out:
# Category
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Sales                        40
# Data Science                 40
# Mechanical Engineer          40
# ETL Developer                40
# Blockchain                   40
# Operations Manager           40
# Arts                         36
# Database                     33
# Health and fitness           30
# PMO                          30
# Electrical Engineering       30
# Business Analyst             28
# DotNet Developer             28
# Automation Testing           26
# Network Security Engineer    25
# Civil Engineer               24
# SAP Developer                24
# Advocate                     20
# Name: count, dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=(15,15))
plt.xticks(rotation=90)
sns.countplot(y="Category", data=resumeDataSet)
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
from matplotlib.gridspec import GridSpec
targetCounts = resumeDataSet['Category'].value_counts()
targetLabels  = resumeDataSet['Category'].unique()
# Make square figures and axes
plt.figure(1, figsize=(25,25))
the_grid = GridSpec(2, 2)


cmap = plt.get_cmap('coolwarm')
colors = [cmap(i) for i in np.linspace(0, 1, 3)]
plt.subplot(the_grid[0, 1], aspect=1, title='CATEGORY DISTRIBUTION')

source_pie = plt.pie(targetCounts, labels=targetLabels, autopct='%1.1f%%', shadow=True, colors=colors)
plt.show()

# %%
import re
def cleanResume(resumeText):
    resumeText = re.sub('http\S+\s*', ' ', resumeText)  # remove URLs
    resumeText = re.sub('RT|cc', ' ', resumeText)  # remove RT and cc
    resumeText = re.sub('#\S+', '', resumeText)  # remove hashtags
    resumeText = re.sub('@\S+', '  ', resumeText)  # remove mentions
    resumeText = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', resumeText)  # remove punctuations
    resumeText = re.sub(r'[^\x00-\x7f]',r' ', resumeText) 
    resumeText = re.sub('\s+', ' ', resumeText)  # remove extra whitespace
    return resumeText
    
resumeDataSet['cleaned_resume'] = resumeDataSet.Resume.apply(lambda x: cleanResume(x))

# %%
# %pip install nltk
# %pip install wordcloud
# %pip install numpy pillow
# %pip install spacy
# Out:
# Requirement already satisfied: nltk in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from nltk) (4.67.0)
# Requirement already satisfied: colorama in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: wordcloud in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from matplotlib->wordcloud) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (2.0.2)
# Requirement already satisfied: pillow in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (10.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: spacy in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (3.8.2)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (0.13.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (4.67.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (75.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from spacy) (2.0.2)
# Requirement already satisfied: language-data>=1.2 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gauri chandel\desktop\ai-ml projects\fraud detection\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Gauri
# [nltk_data]     Chandel\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')  # For POS tagging, if needed
nltk.download('wordnet')  # For lemmatization
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Gauri
# [nltk_data]     Chandel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Gauri Chandel\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to C:\Users\Gauri
# [nltk_data]     Chandel\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
import string
from wordcloud import WordCloud

oneSetOfStopWords = set(stopwords.words('english')+['``',"''"])
totalWords =[]
Sentences = resumeDataSet['Resume'].values
cleanedSentences = ""
for i in range(0,160):
    cleanedText = cleanResume(Sentences[i])
    cleanedSentences += cleanedText
    requiredWords = nltk.word_tokenize(cleanedText)
    for word in requiredWords:
        if word not in oneSetOfStopWords and word not in string.punctuation:
            totalWords.append(word)
    
wordfreqdist = nltk.FreqDist(totalWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)

wc = WordCloud().generate(cleanedSentences)
plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# [('Details', 484), ('Exprience', 446), ('months', 376), ('company', 330), ('description', 310), ('1', 290), ('year', 232), ('January', 216), ('Less', 204), ('Data', 200), ('data', 192), ('Skill', 166), ('Maharashtra', 166), ('6', 164), ('Python', 156), ('Science', 154), ('I', 146), ('Education', 142), ('College', 140), ('The', 126), ('project', 126), ('like', 126), ('Project', 124), ('Learning', 116), ('India', 114), ('Machine', 112), ('University', 112), ('Web', 106), ('using', 104), ('monthsCompany', 102), ('B', 98), ('C', 98), ('SQL', 96), ('time', 92), ('learning', 90), ('Mumbai', 90), ('Pune', 90), ('Arts', 90), ('A', 84), ('application', 84), ('Engineering', 78), ('24', 76), ('various', 76), ('Software', 76), ('Responsibilities', 76), ('Nagpur', 76), ('development', 74), ('Management', 74), ('projects', 74), ('Technologies', 72)]

# %%
from sklearn.preprocessing import LabelEncoder

var_mod = ['Category']
le = LabelEncoder()
for i in var_mod:
    resumeDataSet[i] = le.fit_transform(resumeDataSet[i])

# %% [markdown]
# KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack

requiredText = resumeDataSet['cleaned_resume'].values
requiredTarget = resumeDataSet['Category'].values

word_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    stop_words='english',
    max_features=1500)
word_vectorizer.fit(requiredText)
WordFeatures = word_vectorizer.transform(requiredText)

print ("Feature completed .....")

X_train,X_test,y_train,y_test = train_test_split(WordFeatures,requiredTarget,random_state=0, test_size=0.2)
print(X_train.shape)
print(X_test.shape)
# Out:
# Feature completed .....
# (769, 1500)
# (193, 1500)

# %%
clf = OneVsRestClassifier(KNeighborsClassifier())
clf.fit(X_train, y_train)
prediction = clf.predict(X_test)
print('Accuracy of KNeighbors Classifier on training set: {:.2f}'.format(clf.score(X_train, y_train)))
print('Accuracy of KNeighbors Classifier on test set: {:.2f}'.format(clf.score(X_test, y_test)))

print("\n Classification report for classifier %s:\n%s\n" % (clf, metrics.classification_report(y_test, prediction)))
# Out:
# Accuracy of KNeighbors Classifier on training set: 0.99
# Accuracy of KNeighbors Classifier on test set: 0.99
#
#  Classification report for classifier OneVsRestClassifier(estimator=KNeighborsClassifier()):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      0.80      0.89         5
#            3       1.00      1.00      1.00         9
#            4       1.00      1.00      1.00         6
#            5       0.83      1.00      0.91         5
#            6       1.00      1.00      1.00         9
#            7       1.00      1.00      1.00         7
#            8       1.00      0.91      0.95        11
#            9       1.00      1.00      1.00         9
#           10       1.00      1.00      1.00         8
#           11       0.90      1.00      0.95         9
#           12       1.00      1.00      1.00         5
#           13       1.00      1.00      1.00         9
#           14       1.00      1.00      1.00         7
#           15       1.00      1.00      1.00        19
#           16       1.00      1.00      1.00         3
#           17       1.00      1.00      1.00         4
#           18       1.00      1.00      1.00         5
#           19       1.00      1.00      1.00         6
#           20       1.00      1.00      1.00        11
#           21       1.00      1.00      1.00         4
#           22       1.00      1.00      1.00        13
#           23       1.00      1.00      1.00        15
#           24       1.00      1.00      1.00         8
#
#     accuracy                           0.99       193
#    macro avg       0.99      0.99      0.99       193
# weighted avg       0.99      0.99      0.99       193
